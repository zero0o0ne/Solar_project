# %%
from skimage import io
import numpy as np
import csv
import pandas as pd

lst_1983 = ['samples/1983/1983 (' + str(i+1) + ').jpg' for i in range(69)]
lst_1987 = ['samples/1987/1987 (' + str(i+1) + ').jpg' for i in range(100)]
lst_1989 = ['samples/1989/1989 (' + str(i+1) + ').jpg' for i in range(767)]
lst_1991 = ['samples/1991/1991 (' + str(i+1) + ').jpg' for i in range(1796)]
lst_1998 = ['samples/1998/1998 (' + str(i+1) + ').jpg' for i in range(1186)]
lst_2000 = ['samples/2000/2000 (' + str(i+1) + ').jpg' for i in range(1181)]
lst_2003 = ['samples/2003/2003 (' + str(i+1) + ').jpg' for i in range(400)]
lst_2005 = ['samples/2005/2005 (' + str(i+1) + ').jpg' for i in range(310)]
lst_2021 = ['samples/2021/2021 (' + str(i+1) + ').jpg' for i in range(20)]

# %%
ans_1983 = [int(x) for x in input().split()]
# Out:
# 1 3 1 1 1 1 6 1 2 1 1 4 3 1 0 1 0 1 0 6 1 2 1 1 1 1 3 0 1 0 9 1 1 1 6 10 1 1 1 6 1 2 9 1 1 4 1 3 7 1 6 1 1 6 1 3 7 6 1 0 9 1 1 1 1 1 6 1 10

# %%
ans_1987 = [int(x) for x in input().split()]
# Out:
# 4 7 4 8 4 6 4 7 4 8 4 6 7 4 8 10 4 10 7 10 4 8 10 4 9 4 7 4 8 7 4 8 7 5 0 4 1 7 5 0 4 0 0 1 5 0 5 0 5 0 2 10 3 5 4 5 5 3 5 5 5 5 7 3 9 4 0 1 3 9 0 4 1 4 2 1 2 2 1 2 4 2 4 2 3 4 2 4 3 4 2 10 2 4 2 4 6 10 7 6

# %%
ans_1989 = [int(x) for x in input().split()]
# Out:
# 5 2 0 2 3 2 0 0 2 0 1 1 9 2 1 9 1 1 9 2 0 0 2 0 1 1 2 9 5 2 0 0 2 0 2 2 0 1 2 0 3 1 9 2 0 4 2 0 0 1 2 0 3 1 9 5 2 0 2 5 0 4 2 0 0 2 0 1 2 0 2 3 2 0 0 7 6 10 1 9 5 2 0 5 2 0 4 2 0 0 2 0 1 2 0 3 2 0 2 6 0 7 2 0 2 8 0 9 1 1 9 5 2 0 5 2 0 0 2 0 1 2 0 3 2 0 6 2 0 7 2 0 8 2 2 0 1 9 0 2 0 5 2 0 0 2 0 1 2 0 3 2 0 6 2 0 7 2 0 8 2 0 9 2 1 1 2 0 0 2 3 0 6 2 0 7 10 2 0 8 2 1 0 2 0 9 2 1 1 2 1 2 2 0 6 7 10 2 0 8 2 0 9 2 1 3 2 1 1 2 1 4 2 1 2 2 1 5 10 2 1 6 2 0 6 2 0 7 2 0 8 2 0 9 2 0 9 2 1 1 1 2 1 2 4 1 2 2 1 2 1 10 10 6 2 0 7 2 8 1 7 2 0 9 9 2 1 1 8 2 1 9 2 1 2 2 1 2 1 2 1 6 2 2 7 2 2 1 0 7 8 2 9 2 9 2 1 1 2 1 8 2 1 9 2 2 1 1 2 4 2 1 2 1 6 2 2 1 2 22 2 2 1 2 0 2 2 8 2 0 3 9 2 0 9 2 1 1 2 1 2 2 1 4 2 1 2 1 6 2 2 4 2 2 1 2 2 0 2 2 2 2 2 2 2 3 0 0 9 8 2 0 9 2 1 1 2 1 2 2 1 4 2 1 2 1 2 6 2 4 2 2 2 2 1 2 2 0 2 2 2 2 2 6 2 2 2 1 0 9 2 1 10 9 7 2 1 2 2 1 10 2 1 2 1 6 2 2 4 2 2 2 1 2 10 5 2 2 2 8 2 0 2 2 9 2 2 2 2 2 6 2 1 1 2 1 2 2 1 4 2 1 2 1 6 2 2 4 2 3 0 2 2 2 2 1 2 3 2 1 2 0 2 2 9 2 2 2 2 2 6 2 2 1 
# ...

# %%
ans_1991 = [int(x) for x in input().split()]
# Out:
# 1 5 2 1 9 2 1 8 2 1 6 0 2 2 3 2 2 5 1 3 2 1 9 1 6 2 2 0 2 2 2 2 6 2 1 9 2 1 6 2 2 0 2 2 2 2 2 2 6 8 10 2 2 7 2 1 1 9 2 1 6 2 2 5 2 2 6 2 2 2 8 7 2 2 9 2 1 6 2 2 0 2 2 6 2 2 2 2 7 8 1 1 2 2 2 3 9 3 2 1 6 2 2 3 0 2 2 6 2 2 2 7 2 8 2 3 1 2 2 9 2 3 3 2 10 3 2 2 3 2 2 2 2 6 2 2 2 2 9 3 5 3 3 6 2 7 2 2 2 6 8 3 2 9 2 3 3 5 3 10 2 3 6 2 2 7 2 2 6 2 2 2 2 2 3 8 4 2 3 2 3 3 2 3 2 2 3 7 2 3 8 2 3 6 2 3 9 2 2 7 2 2 2 6 2 2 2 9 3 2 4 8 2 2 3 3 5 3 2 3 2 2 3 7 2 3 6 2 4 0 2 2 2 7 2 2 2 9 2 6 2 2 8 2 2 3 3 3 2 3 7 2 4 1 2 3 6 9 2 2 7 2 2 9 2 2 2 2 6 8 2 3 3 2 3 7 2 4 1 2 3 6 9 2 2 7 2 2 2 2 6 8 2 3 2 2 3 3 2 3 1 2 2 2 3 9 2 4 3 2 3 2 2 3 2 3 3 7 1 2 10 1 4 2 2 10 1 10 4 2 3 9 4 3 2 4 4 2 3 2 2 3 2 3 3 2 4 1 2 3 6 2 2 3 9 2 4 3 2 4 6 4 2 4 2 6 2 2 4 4 8 7 2 4 0 2 3 9 2 4 3 2 4 9 2 4 4 2 2 4 8 2 4 2 0 3 9 3 10 2 4 6 2 4 4 2 2 5 1 0 2 2 2 4 8 2 9 4 0 3 2 6 2 4 2 5 3 2 2 5 1 2 2 2 3 9 2 4 3 10 2 2 5 2 2 5 3 2 5 1 2 2 5 5 6 2 2 2 7 1 2 3 9 2 4 3 2 6 10 2 5 3 10 10 2 2 5 7 8 2 3 2 4 2 5 5 2 5 9 2 6 5 5 8
# ...

# %%
with open('samples_with_marks.csv', 'w') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerow(['filename', 'result'])
    for i in range(len(ans_1983)):
        filewriter.writerow([lst_1983[i], str(ans_1983[i])])
    for i in range(len(ans_1987)):
        filewriter.writerow([lst_1987[i], str(ans_1987[i])])
    for i in range(len(ans_1989)):
        filewriter.writerow([lst_1989[i], str(ans_1989[i])])
    for i in range(len(ans_1991)):
        filewriter.writerow([lst_1991[i], str(ans_1991[i])])

# %%
samples = pd.read_csv('samples_with_marks.csv', delimiter=',')
samples.head()
# Out:
#                     filename  result
# 0  samples/1983/1983 (1).jpg       1
# 1  samples/1983/1983 (2).jpg       3
# 2  samples/1983/1983 (3).jpg       1
# 3  samples/1983/1983 (4).jpg       1
# 4  samples/1983/1983 (5).jpg       1

# %%
im_1983 = io.imread_collection('samples/1983/')

# %%
io.imshow_collection(im_1983)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2ab8417a8f88> in <module>
# ----> 1 io.imshow_collection(im_1983)
#
# ~\anaconda3_64\lib\site-packages\skimage\io\_io.py in imshow_collection(ic, plugin, **plugin_args)
#     177
#     178     """
# --> 179     return call_plugin('imshow_collection', ic, plugin=plugin, **plugin_args)
#     180
#     181
#
# ~\anaconda3_64\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     207                                (plugin, kind))
#     208
# --> 209     return func(*args, **kwargs)
#     210
#     211
#
# ~\anaconda3_64\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py in imshow_collection(ic, *args, **kwargs)
#     177
#     178     if len(ic) < 1:
# --> 179         raise ValueError('Number of images to plot must be greater than 0')
#     180
# ...

# %%
import os
right_1983 = list(map((lambda x: 'right/1983/' + x), os.listdir('right/1983')))
right_1987 = list(map((lambda x: 'right/1987/' + x), os.listdir('right/1987')))
right_1989 = list(map((lambda x: 'right/1989/' + x), os.listdir('right/1989')))
right_1991 = list(map((lambda x: 'right/1991/' + x), os.listdir('right/1991')))

# %%
im_1983 = io.imread_collection(lst_1983)
im_1987 = io.imread_collection(lst_1987)
im_1989 = io.imread_collection(lst_1989)
im_1991 = io.imread_collection(lst_1991)

# %%
right_im_1983 = io.imread_collection(right_1983)
right_im_1987 = io.imread_collection(right_1987)
right_im_1989 = io.imread_collection(right_1989)
right_im_1991 = io.imread_collection(right_1991)

# %%
io.imshow_collection(right_im_1983)

# %%
right_ans_1983 = []
for right in right_im_1983:
    for i in range(len(im_1983)):
        if np.array_equal(im_1983[i], right):
            right_ans_1983.append(ans_1983[i])
# Out:
# [1, 6, 1, 1, 6, 1, 3, 7, 6, 1, 0, 9, 1, 1, 1, 1, 1, 6, 1, 10, 1, 3, 1, 1, 1, 1, 6, 1, 2, 1, 1, 4, 3, 1, 0, 1, 0, 1, 0, 6, 1, 2, 1, 1, 1, 1, 3, 0, 1, 0, 9, 1, 1, 1, 6, 10, 1, 1, 1, 6, 1, 2, 9, 1, 1, 4, 1, 3, 7]

# %%
right_ans_1987 = []
for right in right_im_1987:
    for i in range(len(im_1987)):
        if np.array_equal(im_1987[i], right):
            right_ans_1987.append(ans_1987[i])

# %%
right_ans_1989 = []
for right in right_im_1989:
    for i in range(len(im_1989)):
        if np.array_equal(im_1989[i], right):
            right_ans_1989.append(ans_1989[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-536874686ae6> in <module>
#       3     for i in range(len(im_1989)):
#       4         if np.array_equal(im_1989[i], right):
# ----> 5             right_ans_1989.append(ans_1989[i])
#
# IndexError: list index out of range

# %%
right_ans_1991 = []
for right in right_im_1991:
    for i in range(len(im_1991)):
        if np.array_equal(im_1991[i], right):
            right_ans_1991.append(ans_1991[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-702dd5d62ce6> in <module>
#       3     for i in range(len(im_1991)):
#       4         if np.array_equal(im_1991[i], right):
# ----> 5             right_ans_1991.append(ans_1991[i])
#
# IndexError: list index out of range

# %%
print(len(ans_1991), len(im_1991))
# Out:
# 1795 1796

# %%
print(ans_1991)
# Out:
# [1, 5, 2, 1, 9, 2, 1, 8, 2, 1, 6, 0, 2, 2, 3, 2, 2, 5, 1, 3, 2, 1, 9, 1, 6, 2, 2, 0, 2, 2, 2, 2, 6, 2, 1, 9, 2, 1, 6, 2, 2, 0, 2, 2, 2, 2, 2, 2, 6, 8, 10, 2, 2, 7, 2, 1, 1, 9, 2, 1, 6, 2, 2, 5, 2, 2, 6, 2, 2, 2, 8, 7, 2, 2, 9, 2, 1, 6, 2, 2, 0, 2, 2, 6, 2, 2, 2, 2, 7, 8, 1, 1, 2, 2, 2, 3, 9, 3, 2, 1, 6, 2, 2, 3, 0, 2, 2, 6, 2, 2, 2, 7, 2, 8, 2, 3, 1, 2, 2, 9, 2, 3, 3, 2, 10, 3, 2, 2, 3, 2, 2, 2, 2, 6, 2, 2, 2, 2, 9, 3, 5, 3, 3, 6, 2, 7, 2, 2, 2, 6, 8, 3, 2, 9, 2, 3, 3, 5, 3, 10, 2, 3, 6, 2, 2, 7, 2, 2, 6, 2, 2, 2, 2, 2, 3, 8, 4, 2, 3, 2, 3, 3, 2, 3, 2, 2, 3, 7, 2, 3, 8, 2, 3, 6, 2, 3, 9, 2, 2, 7, 2, 2, 2, 6, 2, 2, 2, 9, 3, 2, 4, 8, 2, 2, 3, 3, 5, 3, 2, 3, 2, 2, 3, 7, 2, 3, 6, 2, 4, 0, 2, 2, 2, 7, 2, 2, 2, 9, 2, 6, 2, 2, 8, 2, 2, 3, 3, 3, 2, 3, 7, 2, 4, 1, 2, 3, 6, 9, 2, 2, 7, 2, 2, 9, 2, 2, 2, 2, 6, 8, 2, 3, 3, 2, 3, 7, 2, 4, 1, 2, 3, 6, 9, 2, 2, 7, 2, 2, 2, 2, 6, 8, 2, 3, 2, 2, 3, 3, 2, 3, 1, 2, 2, 2, 3, 9, 2, 4, 3, 2, 3, 2, 2, 3, 2, 3, 3, 7, 1, 2, 10, 1, 4, 2, 2, 10, 1, 10, 4, 2, 3
# ...

# %%
for i in range(len(ans_1991)):
    if ans_1991[i] == 10:
        print (i+1)
# Out:
# 51
# 125
# 160
# 321
# 326
# 328
# 399
# 440
# 469
# 473
# 474
# 506
# 571
# 612
# 616
# 674
# 688
# 701
# 711
# 784
# 787
# 788
# 799
# 820
# 858
# 882
# 888
# 1179
# 1212
# 1226
# 1418
# 1478
# 1507
# 1511
# 1559
# 1587
# 1593
# 1604
# 1611
# 1677
# 1717
# 1755

# %%
print(ans_1991[51:125])
# Out:
# [2, 2, 7, 2, 1, 1, 9, 2, 1, 6, 2, 2, 5, 2, 2, 6, 2, 2, 2, 8, 7, 2, 2, 9, 2, 1, 6, 2, 2, 0, 2, 2, 6, 2, 2, 2, 2, 7, 8, 1, 1, 2, 2, 2, 3, 9, 3, 2, 1, 6, 2, 2, 3, 0, 2, 2, 6, 2, 2, 2, 7, 2, 8, 2, 3, 1, 2, 2, 9, 2, 3, 3, 2, 10]

# %%
print(ans_1991[:71])
# Out:
# [1, 5, 2, 1, 9, 2, 1, 8, 2, 1, 6, 0, 2, 2, 3, 2, 2, 5, 1, 3, 2, 1, 9, 1, 6, 2, 2, 0, 2, 2, 2, 2, 6, 2, 1, 9, 2, 1, 6, 2, 2, 0, 2, 2, 2, 2, 2, 2, 6, 8, 10, 2, 2, 7, 2, 1, 1, 9, 2, 1, 6, 2, 2, 5, 2, 2, 6, 2, 2, 2, 8]

# %%
ans_1991 = np.append(np.append(ans_1991[:71], 2), ans_1991[71:])

# %%
print(len(ans_1991))
# Out:
# 1796

# %%
for i in range(len(ans_1989)):
    if ans_1989[i] == 10:
        print (i+1)
# Out:
# 78
# 177
# 197
# 219
# 252
# 253
# 413
# 421
# 435
# 533
# 536
# 559
# 630
# 661
# 698
# 701
# 736

# %%
print(ans_1989[252:413])
# Out:
# [10, 6, 2, 0, 7, 2, 8, 1, 7, 2, 0, 9, 9, 2, 1, 1, 8, 2, 1, 9, 2, 1, 2, 2, 1, 2, 1, 2, 1, 6, 2, 2, 7, 2, 2, 1, 0, 7, 8, 2, 9, 2, 9, 2, 1, 1, 2, 1, 8, 2, 1, 9, 2, 2, 1, 1, 2, 4, 2, 1, 2, 1, 6, 2, 2, 1, 2, 22, 2, 2, 1, 2, 0, 2, 2, 8, 2, 0, 3, 9, 2, 0, 9, 2, 1, 1, 2, 1, 2, 2, 1, 4, 2, 1, 2, 1, 6, 2, 2, 4, 2, 2, 1, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 3, 0, 0, 9, 8, 2, 0, 9, 2, 1, 1, 2, 1, 2, 2, 1, 4, 2, 1, 2, 1, 2, 6, 2, 4, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2, 2, 2, 6, 2, 2, 2, 1, 0, 9, 2, 1, 10]

# %%
print(ans_1989.index(22))
# Out:
# 319

# %%
ans_1989 = np.append(np.append(ans_1989[:319], [2, 2]), ans_1989[320:])

# %%
print(len(ans_1989))
# Out:
# 767

# %%
right_ans_1989 = []
for right in right_im_1989:
    for i in range(len(im_1989)):
        if np.array_equal(im_1989[i], right):
            right_ans_1989.append(ans_1989[i])

# %%
print(len(right_ans_1989))
# Out:
# 767

# %%
right_ans_1991 = []
for right in right_im_1991:
    for i in range(len(im_1991)):
        if np.array_equal(im_1991[i], right):
            right_ans_1991.append(ans_1991[i])

# %%
print(right_ans_1991)
# Out:
# [2, 2, 1, 2, 1, 7, 2, 1, 3, 2, 1, 5, 2, 2, 1, 1, 8, 9, 2, 1, 7, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 3, 1, 7, 2, 1, 5, 2, 1, 9, 2, 1, 8, 2, 1, 6, 0, 2, 2, 3, 2, 2, 5, 1, 3, 2, 1, 9, 1, 6, 2, 2, 0, 2, 2, 2, 2, 6, 2, 1, 9, 2, 1, 6, 2, 2, 0, 2, 2, 2, 2, 2, 2, 6, 8, 10, 2, 2, 7, 2, 1, 1, 9, 2, 1, 6, 2, 2, 5, 2, 2, 6, 2, 2, 2, 8, 2, 7, 2, 2, 9, 2, 1, 6, 2, 2, 0, 2, 2, 6, 2, 2, 2, 2, 7, 8, 1, 1, 2, 2, 2, 3, 9, 3, 2, 1, 6, 2, 2, 3, 0, 2, 2, 6, 2, 2, 2, 7, 2, 8, 2, 3, 1, 2, 2, 9, 2, 3, 3, 2, 10, 3, 2, 2, 3, 2, 2, 2, 2, 6, 2, 2, 2, 2, 9, 3, 5, 3, 3, 6, 2, 7, 2, 2, 2, 6, 8, 3, 2, 9, 2, 3, 3, 5, 3, 10, 2, 3, 6, 2, 2, 7, 2, 2, 6, 2, 2, 2, 2, 2, 3, 8, 4, 2, 3, 2, 3, 3, 2, 3, 2, 2, 3, 7, 2, 3, 8, 2, 3, 6, 2, 3, 9, 2, 2, 7, 2, 2, 2, 6, 2, 2, 2, 9, 3, 2, 4, 8, 2, 2, 3, 3, 5, 3, 2, 3, 2, 2, 3, 7, 2, 3, 6, 2, 4, 0, 2, 2, 2, 7, 2, 2, 2, 9, 2, 6, 2, 2, 8, 2, 2, 3, 3, 3, 2, 3, 7, 2, 4, 1, 2, 3, 6, 9, 2, 2, 7, 2, 2, 9, 2, 2, 2, 2, 6, 8, 2, 3, 3, 2, 3, 7, 2, 4, 1, 2, 3, 6, 9, 2, 2, 7, 2, 2, 2, 2, 6, 8, 2, 3, 2, 2
# ...

# %%
with open('samples_with_marks.csv', 'w') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerow(['filename', 'result'])
    for i in range(len(ans_1983)):
        filewriter.writerow([right_1983[i], str(right_ans_1983[i])])
    for i in range(len(ans_1987)):
        filewriter.writerow([right_1987[i], str(right_ans_1987[i])])
    for i in range(len(ans_1989)):
        filewriter.writerow([right_1989[i], str(right_ans_1989[i])])
    for i in range(len(ans_1991)):
        filewriter.writerow([right_1991[i], str(right_ans_1991[i])])

# %%
samples = pd.read_csv('samples_with_marks.csv', delimiter=',')
samples.head()
# Out:
#                                  filename  result
# 0  right/1983/loc-d19830101_0163_1393.jpg       1
# 1  right/1983/loc-d19830101_0176_1396.jpg       6
# 2  right/1983/loc-d19830101_0487_1436.jpg       1
# 3  right/1983/loc-d19830102_0157_1371.jpg       1
# 4  right/1983/loc-d19830102_0170_1374.jpg       6

# %%
import os
right_1998 = list(map((lambda x: 'right/1998/' + x), os.listdir('right/1998')))
right_2000 = list(map((lambda x: 'right/2000/' + x), os.listdir('right/2000')))
right_2003 = list(map((lambda x: 'right/2003/' + x), os.listdir('right/2003')))
right_2005 = list(map((lambda x: 'right/2005/' + x), os.listdir('right/2005')))
right_2021 = list(map((lambda x: 'right/2021/' + x), os.listdir('right/2021')))

# %%
ans_1998 = input().split()
print(ans_1998)
# Out:
# 8 0 8 2 8 4 8 5 1 0 8 8 6 8 5 8 0 4 8 5 10 10 8 0 8 10 4 8 8 8 4 8 5 8 7 8 0 8 4 8 8 6 10 10 10 8 4 10 8 5 10 8 8 10 8 6 10 8 8 5 8 9 8 9 8 5 10 8 6 9 2 9 1 9 0 8 5 8 8 8 6 9 2 10 9 10 1 10 8 5 8 8 8 7 9 2 9 1 8 8 7 9 2 9 1 10 8 7 9 2 9 1 8 7 9 2 9 1 10 8 7 2 10 9 10 1 10 10 8 7 9 2 9 1 8 7 9 3 9 2 10 3 10 9 2 9 9 5 10 9 3 9 9 2 1 10 9 1 9 2 9 6 10 9 1 9 7 10 9 8 10 10 10 10 9 7 9 8 9 9 9 7 10 10 9 8 9 9 9 8 9 9 1 0 1 0 1 10 9 8 9 1 0 0 0 1 9 8 9 9 1 0 1 8 10 9 9 0 2 1 0 1 1 0 3 9 8 9 9 10 1 0 1 1 1 0 0 4 3 1 0 9 9 1 0 1 1 0 4 1 0 3 1 0 5 1 0 6 9 9 1 0 1 1 1 0 0 4 3 1 1 0 0 6 9 9 1 0 8 1 0 1 10 1 0 9 10 10 1 10 1 0 7 10 3 10 1 0 6 10 1 0 6 10 7 1 1 10 9 1 1 1 0 1 1 0 9 1 1 0 0 7 3 1 0 4 10 1 1 0 1 0 1 1 0 9 1 1 1 1 0 3 1 0 4 1 1 2 1 1 3 1 1 0 10 1 0 1 1 0 9 1 1 1 1 0 3 1 1 1 1 3 1 1 0 1 0 9 1 1 1 1 1 4 1 0 3 1 1 2 1 1 3 1 1 5 1 1 1 0 1 6 1 1 7 1 1 8 10 1 0 10 9 10 1 1 1 1 0 3 1 1 3 1 1 0 1 1 6 1 1 7 1 1 8 1 1 1 0 1 3 1 1 2 1 1 9 1 1 3 1 1 0 1 1 6 1 2 10 0 1 1 7 1 2 1 1 1 8 1 2 2 1 3 
# ...

# %%
print(len(ans_1998))
ans_1998 = list(map(lambda x: int(x), ans_1998))
# Out:
# 1184

# %%
print(len([i for i in ans_1998 if i == 7]))
# Out:
# 37

# %%
print([right_1998[i] for i in range(len(right_1998) - 2) if ans_1998[i] == 7])
# Out:
# ['right/1998/loc-d19980506_1435_1387.jpg', 'right/1998/loc-d19980513_0704_1397.jpg', 'right/1998/loc-d19980514_0551_1403.jpg', 'right/1998/loc-d19980515_0422_1414.jpg', 'right/1998/loc-d19980516_0308_1404.jpg', 'right/1998/loc-d19980517_0242_1386.jpg', 'right/1998/loc-d19980518_0212_1412.jpg', 'right/1998/loc-d19980519_0176_1380.jpg', 'right/1998/loc-d19980523_0785_0937.jpg', 'right/1998/loc-d19980525_0484_0949.jpg', 'right/1998/loc-d19980526_0338_0955.jpg', 'right/1998/loc-d19980606_1114_1232.jpg', 'right/1998/loc-d19980607_0682_0904.jpg', 'right/1998/loc-d19980608_0850_1272.jpg', 'right/1998/loc-d19980611_1349_0758.jpg', 'right/1998/loc-d19980612_1295_0765.jpg', 'right/1998/loc-d19980613_1176_0753.jpg', 'right/1998/loc-d19980615_0943_0754.jpg', 'right/1998/loc-d19980616_0799_0783.jpg', 'right/1998/loc-d19980617_0672_0768.jpg', 'right/1998/loc-d19980618_0561_0777.jpg', 'right/1998/loc-d19980619_0440_0764.jpg', 'right/1998/loc-d19980620_0853_1532.jpg', 'right/1998/loc-d19980621_0721_
# ...

# %%
print(right_1998.index('right/1998/loc-d19980619_0440_0764.jpg'), right_1998.index('right/1998/loc-d19980620_0853_1532.jpg'))
# Out:
# 555 581

# %%
print(ans_1998[554:582])
# Out:
# [1, 7, 1, 1, 8, 1, 2, 5, 1, 2, 1, 2, 3, 1, 1, 710, 1, 2, 5, 1, 2, 2, 1, 2, 6, 1, 2, 7]

# %%
import numpy as np
ans_1998 = np.append(np.append(ans_1998[:ans_1998.index(710)], [7, 10]), ans_1998[ans_1998.index(710) + 1:])

# %%
print(ans_1998[554:582])
# Out:
# [ 1  7  1  1  8  1  2  5  1  2  1  2  3  1  1  7 10  1  2  5  1  2  2  1
#   2  6  1  2]

# %%
print([right_1998[i] for i in range(len(right_1998) - 2) if ans_1998[i] == 7])
# Out:
# ['right/1998/loc-d19980506_1435_1387.jpg', 'right/1998/loc-d19980513_0704_1397.jpg', 'right/1998/loc-d19980514_0551_1403.jpg', 'right/1998/loc-d19980515_0422_1414.jpg', 'right/1998/loc-d19980516_0308_1404.jpg', 'right/1998/loc-d19980517_0242_1386.jpg', 'right/1998/loc-d19980518_0212_1412.jpg', 'right/1998/loc-d19980519_0176_1380.jpg', 'right/1998/loc-d19980523_0785_0937.jpg', 'right/1998/loc-d19980525_0484_0949.jpg', 'right/1998/loc-d19980526_0338_0955.jpg', 'right/1998/loc-d19980606_1114_1232.jpg', 'right/1998/loc-d19980607_0682_0904.jpg', 'right/1998/loc-d19980608_0850_1272.jpg', 'right/1998/loc-d19980611_1349_0758.jpg', 'right/1998/loc-d19980612_1295_0765.jpg', 'right/1998/loc-d19980613_1176_0753.jpg', 'right/1998/loc-d19980615_0943_0754.jpg', 'right/1998/loc-d19980616_0799_0783.jpg', 'right/1998/loc-d19980617_0672_0768.jpg', 'right/1998/loc-d19980618_0561_0777.jpg', 'right/1998/loc-d19980619_0440_0764.jpg', 'right/1998/loc-d19980620_0350_0737.jpg', 'right/1998/loc-d19980620_0872_
# ...

# %%
1012_1434 
print(right_1998.index('right/1998/loc-d19980701_1162_1476.jpg'), right_1998.index('right/1998/loc-d19980702_1012_1434.jpg'))
# Out:
# 817 840

# %%
print(ans_1998[817:841])
# Out:
# [ 7  8 10  1  3  9  1  4  1  1  4  2  1  3 13  1  1  3  1  4  1  3 10  7]

# %%
ans_1998 = [i for i in ans_1998]
ans_1998 = np.append(np.append(ans_1998[:ans_1998.index(13)], [1, 3]), ans_1998[ans_1998.index(13) + 1:])

# %%
print(ans_1998[817:841])
# Out:
# [ 7  8 10  1  3  9  1  4  1  1  4  2  1  3  1  3  1  1  3  1  4  1  3 10]

# %%
import pandas as pd
frame = pd.read_csv('samples_with_marks.csv', delimiter=',')
frame1 = [[right_1998[i], ans_1998[i]] for i in range(len(ans_1998))]
frame.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 2727  right/1991/loc-d19910705_1224_0658.jpg       2
# 2728  right/1991/loc-d19910705_1287_1404.jpg       3
# 2729  right/1991/loc-d19910705_1303_1404.jpg       5
# 2730  right/1991/loc-d19910705_1320_1404.jpg       5
# 2731  right/1991/loc-d19910705_1378_1024.jpg       6
#
# [2732 rows x 2 columns]>

# %%
frame1 = pd.DataFrame(frame1)
frame1.columns = ['filename',  'result']
frame1.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1998/loc-d19980502_0625_1341.jpg       8
# 1     right/1998/loc-d19980502_0643_1342.jpg       0
# 2     right/1998/loc-d19980502_0914_1391.jpg       8
# 3     right/1998/loc-d19980502_0932_1390.jpg       2
# 4     right/1998/loc-d19980502_1080_0828.jpg       8
# ...                                      ...     ...
# 1181  right/1998/loc-d19980723_1358_0997.jpg       6
# 1182  right/1998/loc-d19980723_1360_0749.jpg       9
# 1183  right/1998/loc-d19980723_1375_0990.jpg       7
# 1184  right/1998/loc-d19980723_1398_1314.jpg       6
# 1185  right/1998/loc-d19980723_1414_1311.jpg       5
#
# [1186 rows x 2 columns]>

# %%
frame = frame.append(frame1, ignore_index = True)

# %%
frame.shape
frame.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 3913  right/1998/loc-d19980723_1358_0997.jpg       6
# 3914  right/1998/loc-d19980723_1360_0749.jpg       9
# 3915  right/1998/loc-d19980723_1375_0990.jpg       7
# 3916  right/1998/loc-d19980723_1398_1314.jpg       6
# 3917  right/1998/loc-d19980723_1414_1311.jpg       5
#
# [3918 rows x 2 columns]>

# %%
frame.to_csv('samples_with_marks.csv', sep=' ')
frame.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 3913  right/1998/loc-d19980723_1358_0997.jpg       6
# 3914  right/1998/loc-d19980723_1360_0749.jpg       9
# 3915  right/1998/loc-d19980723_1375_0990.jpg       7
# 3916  right/1998/loc-d19980723_1398_1314.jpg       6
# 3917  right/1998/loc-d19980723_1414_1311.jpg       5
#
# [3918 rows x 2 columns]>

# %%
samples = pd.read_csv('samples_with_marks.csv', delimiter=',')
samples.head()
# Out:
#                               filename result
# 0  0 right/1983/loc-d19830101_0163_1393.jpg 1
# 1  1 right/1983/loc-d19830101_0176_1396.jpg 6
# 2  2 right/1983/loc-d19830101_0487_1436.jpg 1
# 3  3 right/1983/loc-d19830102_0157_1371.jpg 1
# 4  4 right/1983/loc-d19830102_0170_1374.jpg 6

# %%
ans_1998 = input().split()
print(ans_1998)
print(len(ans_1998))
ans_1998 = list(map(lambda x: int(x), ans_1998))
# Out:
# 1 8 1 0 7 9 1 9 1 1 9 9 4 2 1 9 1 6 9 5 1 1 10 8 7 0 9 1 9 1 1 1 9 9 4 2 1 9 6 1 9 1 7 1 1 8 9 9 0 1 1 9 1 2 9 4 1 9 6 1 9 5 1 9 7 1 9 1 2 9 1 9 1 6 9 1 9 8 1 9 7 1 9 2 1 9 1 4 9 9 1 9 1 6 9 5 10 1 9 8 2 1 9 7 2 0 1 2 0 3 1 10 10 10 10 1 1 9 5 2 0 8 10 2 0 3 1 9 7 2 0 4 2 0 2 0 6 7 2 0 9 1 9 5 2 0 8 3 1 9 7 2 0 4 2 2 1 0 0 5 10 6 7 9 2 0 8 1 9 7 2 0 2 4 2 1 0 0 6 2 0 7 2 9 1 2 1 1 2 2 0 2 4 0 5 2 0 6 2 0 7 9 2 1 1 2 1 2 2 1 3 2 1 4 2 0 2 4 0 5 2 0 6 1 2 0 7 2 1 6 2 0 9 2 1 1 2 1 2 2 1 7 2 1 3 2 5 0 4 2 6 2 1 8 2 0 10 2 1 6 2 1 9 2 0 9 2 1 1 2 1 10 2 1 2 7 1 10 3 2 10 2 1 0 2 0 5 4 2 0 6 2 1 8 2 0 2 7 2 1 2 0 9 2 1 1 2 2 2 10 2 1 10 2 2 1 7 2 1 3 2 10 2 10 0 2 1 0 10 2 0 2 5 0 4 2 0 6 2 1 8 2 0 7 2 2 1 10 2 1 1 2 1 2 10 2 1 3 2 1 7 2 1 3 2 2 2 2 0 3 2 10 6 2 0 2 4 4 2 2 5 1 8 2 2 1 2 0 9 2 1 1 2 2 1 1 2 3 2 1 7 2 1 3 2 2 2 3 2 2 6 2 0 10 2 0 6 2 1 8 2 2 1 1 3 2 2 1 7 2 1 3 2 2 3 2 2 2 2 0 6 2 2 7 2 2 8 2 1 2 2 1 7 2 1 3 2 2 3 2 2 2 2 0 6 2 2 7 2 2 9 2 2 8 2 3 0 2 1 2 2 3 1 2 1 7 2 1 3
# ...

# %%
import pandas as pd
frame = pd.read_csv('samples_with_marks.csv')
frame_health = [[frame.iloc[i][0].split()[1], frame.iloc[i][0].split()[2]] for i in range(frame.shape[0])]
frame_health = pd.DataFrame(frame_health)
frame_health.columns = ['filename',  'result']
frame_health.head
# Out:
# <bound method NDFrame.head of                                     filename result
# 0     right/1983/loc-d19830101_0163_1393.jpg      1
# 1     right/1983/loc-d19830101_0176_1396.jpg      6
# 2     right/1983/loc-d19830101_0487_1436.jpg      1
# 3     right/1983/loc-d19830102_0157_1371.jpg      1
# 4     right/1983/loc-d19830102_0170_1374.jpg      6
# ...                                      ...    ...
# 3913  right/1998/loc-d19980723_1358_0997.jpg      6
# 3914  right/1998/loc-d19980723_1360_0749.jpg      9
# 3915  right/1998/loc-d19980723_1375_0990.jpg      7
# 3916  right/1998/loc-d19980723_1398_1314.jpg      6
# 3917  right/1998/loc-d19980723_1414_1311.jpg      5
#
# [3918 rows x 2 columns]>

# %%
frame1 = [[right_2000[i], ans_1998[i]] for i in range(len(ans_1998))]
frame1 = pd.DataFrame(frame1)
frame1.columns = ['filename',  'result']
frame1.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/2000/loc-d20000501_0177_1342.jpg       1
# 1     right/2000/loc-d20000501_0192_1341.jpg       8
# 2     right/2000/loc-d20000501_0196_0931.jpg       1
# 3     right/2000/loc-d20000501_0208_1341.jpg       0
# 4     right/2000/loc-d20000501_0209_0930.jpg       7
# ...                                      ...     ...
# 1176  right/2000/loc-d20000622_1377_0906.jpg       2
# 1177  right/2000/loc-d20000622_1425_1365.jpg       6
# 1178  right/2000/loc-d20000622_1453_0993.jpg       2
# 1179  right/2000/loc-d20000622_1478_0996.jpg       8
# 1180  right/2000/loc-d20000622_1496_0993.jpg       8
#
# [1181 rows x 2 columns]>

# %%
frame = frame_health.append(frame1, ignore_index = True)
frame.head
frame.iloc[0]
# Out:
# filename    right/1983/loc-d19830101_0163_1393.jpg
# result                                           1
# Name: 0, dtype: object

# %%
frame[['filename',  'result']].to_csv('samples_with_marks.csv', sep=',', index = False)

# %%
samples = pd.read_csv('samples_with_marks.csv')
samples.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 5094  right/2000/loc-d20000622_1377_0906.jpg       2
# 5095  right/2000/loc-d20000622_1425_1365.jpg       6
# 5096  right/2000/loc-d20000622_1453_0993.jpg       2
# 5097  right/2000/loc-d20000622_1478_0996.jpg       8
# 5098  right/2000/loc-d20000622_1496_0993.jpg       8
#
# [5099 rows x 2 columns]>

# %%
ans_2003 = input().split()
print(ans_2003)
print(len(ans_2003))
ans_2003 = list(map(lambda x: int(x), ans_2003))
# Out:
# 9 6 1 1 0 1 0 3 1 0 4 1 0 5 1 0 8 1 1 1 1 1 2 1 0 3 1 0 1 0 5 1 0 8 1 1 3 1 1 2 1 0 4 0 5 1 1 3 1 1 4 1 0 4 1 0 5 1 0 8 1 1 3 1 1 2 1 1 1 4 1 5 1 1 0 10 0 5 1 0 8 1 1 3 1 1 1 1 1 1 5 4 10 10 1 0 10 8 1 1 3 1 1 10 1 1 6 1 1 7 1 1 5 1 1 4 1 1 3 1 1 2 1 1 6 1 1 4 1 1 2 1 1 9 1 1 1 2 1 1 1 2 9 1 2 2 1 1 2 1 2 3 1 1 1 9 2 1 1 2 2 1 1 2 1 2 3 1 1 1 9 2 1 1 2 2 1 2 4 1 1 1 9 2 1 1 2 1 2 1 1 2 1 9 1 1 2 1 10 5 1 10 10 1 2 1 1 1 9 1 2 2 1 2 5 1 2 10 6 1 1 1 2 2 1 2 1 2 8 1 1 1 9 1 2 2 1 2 9 1 3 0 1 2 6 2 1 2 9 1 3 0 1 2 6 1 3 1 10 1 2 2 1 2 9 1 2 6 1 3 1 1 2 2 1 2 9 1 2 6 1 3 1 1 3 4 1 1 3 3 3 2 1 2 2 10 1 2 6 1 3 1 1 3 4 1 1 3 3 1 2 5 3 3 1 2 6 1 3 1 1 1 3 3 2 4 1 3 3 1 3 1 1 3 1 4 3 3 1 3 10 1 1 1 3 3 5 1 3 3 4 1 3 1 1 3 3 1 3 1 3 1 1 3 3 1 3 4 1 3 6 3 1 1 3 3 1 3 4 1 3 6 1 3 1 1 3 4 1 3 6 1 3 1 1 3 4 1 3 6
# ...

# %%
ans_2005 = input().split()
print(ans_2005)
print(len(ans_2005))
ans_2005 = list(map(lambda x: int(x), ans_2005))
# Out:
# 4 5 3 4 4 3 4 6 1 4 4 4 3 4 4 6 7 4 3 4 4 6 4 3 4 6 7 4 3 4 7 4 6 4 3 10 4 7 4 6 4 6 4 8 9 4 6 4 7 4 8 10 4 9 4 10 6 4 7 5 0 5 1 4 8 4 9 4 6 4 7 5 0 4 1 4 4 8 9 5 2 4 6 4 7 5 0 5 1 4 8 5 2 4 6 5 1 5 2 5 1 4 8 5 2 10 8 5 2 4 8 5 2 4 8 5 2 10 5 3 8 10 5 3 5 3 5 3 5 4 5 5 6 5 5 4 5 6 5 5 5 5 5 6 10 10 5 7 5 5 6 5 5 7 5 5 6 5 6 5 6 5 9 5 8 5 6 5 9 5 8 5 6 6 0 5 9 5 8 6 1 5 6 6 0 5 9 10 6 1 10 6 2 5 6 6 0 6 1 6 2 6 1 6 2 6 1 6 2 6 3 2 3 5 6 4 6 1 6 2 6 3 10 6 5 6 4 6 1 6 2 6 6 6 3 6 5 1 6 2 10 6 3 6 5 10 6 1 6 2 6 7 6 3 6 5 6 8 6 1 6 6 3 6 6 8 6 2 6 3 6 6 8 10 5 6 3 6 5 6 9 7 0 6 3 6 5 6 9 7 0 6 5 7 0 7 1 7 2 7 0 7 2 0 7 2 7 0 7 2
# ...

# %%
frame1 = [[right_2003[i], ans_2003[i]] for i in range(len(ans_2003))]
frame1 = pd.DataFrame(frame1)
frame1.columns = ['filename',  'result']
frame1.head
# Out:
# <bound method NDFrame.head of                                    filename  result
# 0    right/2003/loc-d20030501_0168_1311.jpg       9
# 1    right/2003/loc-d20030501_0182_1314.jpg       6
# 2    right/2003/loc-d20030501_0247_1278.jpg       1
# 3    right/2003/loc-d20030501_0260_1277.jpg       1
# 4    right/2003/loc-d20030501_0276_1279.jpg       0
# ..                                      ...     ...
# 395  right/2003/loc-d20030531_0546_1561.jpg       3
# 396  right/2003/loc-d20030531_0562_1564.jpg       4
# 397  right/2003/loc-d20030531_1281_1092.jpg       1
# 398  right/2003/loc-d20030531_1295_1094.jpg       3
# 399  right/2003/loc-d20030531_1310_1097.jpg       6
#
# [400 rows x 2 columns]>

# %%
frame2 = [[right_2005[i], ans_2005[i]] for i in range(len(ans_2005))]
frame2 = pd.DataFrame(frame2)
frame2.columns = ['filename',  'result']
frame2.head
# Out:
# <bound method NDFrame.head of                                    filename  result
# 0    right/2005/loc-d20050501_0510_1217.jpg       4
# 1    right/2005/loc-d20050501_0736_1246.jpg       5
# 2    right/2005/loc-d20050501_0848_1269.jpg       3
# 3    right/2005/loc-d20050502_0397_1257.jpg       4
# 4    right/2005/loc-d20050502_0693_1285.jpg       4
# ..                                      ...     ...
# 305  right/2005/loc-d20050619_1414_1289.jpg       2
# 306  right/2005/loc-d20050620_0335_1444.jpg       7
# 307  right/2005/loc-d20050620_0353_1447.jpg       0
# 308  right/2005/loc-d20050620_1273_1327.jpg       7
# 309  right/2005/loc-d20050620_1289_1331.jpg       2
#
# [310 rows x 2 columns]>

# %%
frame.head
# Out:
# <bound method NDFrame.head of                                     filename result
# 0     right/1983/loc-d19830101_0163_1393.jpg      1
# 1     right/1983/loc-d19830101_0176_1396.jpg      6
# 2     right/1983/loc-d19830101_0487_1436.jpg      1
# 3     right/1983/loc-d19830102_0157_1371.jpg      1
# 4     right/1983/loc-d19830102_0170_1374.jpg      6
# ...                                      ...    ...
# 5094  right/2000/loc-d20000622_1377_0906.jpg      2
# 5095  right/2000/loc-d20000622_1425_1365.jpg      6
# 5096  right/2000/loc-d20000622_1453_0993.jpg      2
# 5097  right/2000/loc-d20000622_1478_0996.jpg      8
# 5098  right/2000/loc-d20000622_1496_0993.jpg      8
#
# [5099 rows x 2 columns]>

# %%
frame = frame.append(frame1, ignore_index = True)
frame = frame.append(frame2, ignore_index = True)
frame.head
# Out:
# <bound method NDFrame.head of                                     filename result
# 0     right/1983/loc-d19830101_0163_1393.jpg      1
# 1     right/1983/loc-d19830101_0176_1396.jpg      6
# 2     right/1983/loc-d19830101_0487_1436.jpg      1
# 3     right/1983/loc-d19830102_0157_1371.jpg      1
# 4     right/1983/loc-d19830102_0170_1374.jpg      6
# ...                                      ...    ...
# 5804  right/2005/loc-d20050619_1414_1289.jpg      2
# 5805  right/2005/loc-d20050620_0335_1444.jpg      7
# 5806  right/2005/loc-d20050620_0353_1447.jpg      0
# 5807  right/2005/loc-d20050620_1273_1327.jpg      7
# 5808  right/2005/loc-d20050620_1289_1331.jpg      2
#
# [5809 rows x 2 columns]>

# %%
frame.to_csv('samples_with_marks.csv', sep=',', index = False)
samples = pd.read_csv('samples_with_marks.csv')
samples.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 5804  right/2005/loc-d20050619_1414_1289.jpg       2
# 5805  right/2005/loc-d20050620_0335_1444.jpg       7
# 5806  right/2005/loc-d20050620_0353_1447.jpg       0
# 5807  right/2005/loc-d20050620_1273_1327.jpg       7
# 5808  right/2005/loc-d20050620_1289_1331.jpg       2
#
# [5809 rows x 2 columns]>

# %%
import numpy as np
import pandas as pd
from skimage import io
import copy

frame = pd.read_csv('samples_with_marks.csv')
frame.head
filenames = np.asarray(frame['filename'])
result = np.asarray(frame['result'])

Y_ = np.ndarray((filenames.size, 32, 32))
for i in range(filenames.size):
    X = io.imread(filenames[i], as_gray = True) 
    #максимальная длина картинки в наших данных - 31
    X = np.r_[np.c_[X, np.ones((X.size // X[1].size, 32 - X[1].size))], np.ones((32-X.size // X[1].size, 32))] 
    Y_[i] = X
Y_ = 1-Y_
Y_ = Y_.astype('float32')

ind = [i for i in range(len(result)) if result[i] == 10]
print(ind)
# Out:
# [11, 19, 21, 49, 50, 55, 97, 103, 121, 123, 125, 128, 142, 149, 157, 164, 174, 282, 313, 381, 401, 423, 445, 456, 457, 528, 618, 626, 640, 738, 741, 764, 835, 866, 903, 906, 996, 1021, 1026, 1096, 1131, 1272, 1292, 1297, 1298, 1299, 1370, 1411, 1431, 1440, 1444, 1445, 1477, 1542, 1583, 1587, 1638, 1640, 1645, 1659, 1672, 1677, 1679, 1682, 1755, 1758, 1759, 1770, 1791, 1829, 1853, 1859, 1881, 2150, 2183, 2197, 2389, 2449, 2478, 2482, 2530, 2558, 2564, 2575, 2582, 2597, 2648, 2650, 2688, 2726, 2740, 2752, 2753, 2757, 2774, 2775, 2776, 2779, 2782, 2785, 2788, 2798, 2815, 2817, 2819, 2837, 2850, 2854, 2856, 2858, 2859, 2872, 2874, 2880, 2887, 2894, 2899, 2902, 2903, 2904, 2905, 2914, 2915, 2929, 2946, 2961, 3014, 3018, 3019, 3025, 3027, 3031, 3035, 3039, 3058, 3086, 3140, 3143, 3145, 3190, 3219, 3223, 3232, 3240, 3252, 3269, 3273, 3302, 3344, 3355, 3360, 3367, 3373, 3394, 3429, 3477, 3551, 3572, 3606, 3612, 3712, 3730, 3731, 3735, 3739, 3756, 3757, 3759, 3768, 3784, 3786, 3795, 3804, 381
# ...

# %%
io.imshow_collection([Y_[i] for i in ind[130:]])

# %%
numb = input().split()
# Out:
# 1 3 4 5 13 14 15 16 18 33 34 49 58 64 73 86 87 88 95 101 108 137 145 162 163 164 165 167 168 169 170 171 172 173 174 177 180 182 183 203 204 220 225 226 227 228 233 234 235 236 238

# %%
for i in numb:
    result[ind[int(i)-1]] = 11
io.imshow_collection([Y_[i] for i in range(Y_.shape[0]) if result[i] == 11])

# %%
frame2 = [[filenames[i], result[i]] for i in range(len(result))]
frame2 = pd.DataFrame(frame2)
frame2.columns = ['filename',  'result']
frame2.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 5804  right/2005/loc-d20050619_1414_1289.jpg       2
# 5805  right/2005/loc-d20050620_0335_1444.jpg       7
# 5806  right/2005/loc-d20050620_0353_1447.jpg       0
# 5807  right/2005/loc-d20050620_1273_1327.jpg       7
# 5808  right/2005/loc-d20050620_1289_1331.jpg       2
#
# [5809 rows x 2 columns]>

# %%
frame2.to_csv('samples_with_marks.csv', sep=',', index = False)
samples = pd.read_csv('samples_with_marks.csv')
samples.head
# Out:
# <bound method NDFrame.head of                                     filename  result
# 0     right/1983/loc-d19830101_0163_1393.jpg       1
# 1     right/1983/loc-d19830101_0176_1396.jpg       6
# 2     right/1983/loc-d19830101_0487_1436.jpg       1
# 3     right/1983/loc-d19830102_0157_1371.jpg       1
# 4     right/1983/loc-d19830102_0170_1374.jpg       6
# ...                                      ...     ...
# 5804  right/2005/loc-d20050619_1414_1289.jpg       2
# 5805  right/2005/loc-d20050620_0335_1444.jpg       7
# 5806  right/2005/loc-d20050620_0353_1447.jpg       0
# 5807  right/2005/loc-d20050620_1273_1327.jpg       7
# 5808  right/2005/loc-d20050620_1289_1331.jpg       2
#
# [5809 rows x 2 columns]>
